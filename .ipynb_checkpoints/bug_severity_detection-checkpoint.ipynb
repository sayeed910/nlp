# %%
import pandas as pd

# %%
df = pd.read_excel('data/Eclipse_4sourcev1.xls', header=None, names=['severity', 'summary', 'description'], usecols=[0, 1, 2])
df
# Out:
#       severity                                            summary  \
# 0            3                       renam project releas gdhahf
# 1            2                          except disconnect gf qca
# 2            2  dbcs pde pluin manifest editor display dbc cha...
# 3            2  dbc except thread launch plugin project code r...
# 4            2  debugg show sourc type gener fail execut runna...
# 5            2                contribut view startup plugin gdvl
# 6            5           wizard disabl finish valid select geapg
# 7            4                     project wizard focu text gf u
# 8            2                    jface wizard banner high gf qi
# 9            3                   jre lib append buildpath gf taz
# 10           4  compil lf run class miss implement interfac fn...
# 11           4      creat class creat entri local histori ge toc
# 12           2            hierarchi updat chang classpath gf qsw
# 13           4  smoke compil error introduc renam refactor gfb...
# 14           3                  java outlin updat problem geufvw
# 15           4  gotomark set sourc rang updat outlin view g sx...
# 16           4          extract method constructor remind geynsb
# 17           3         leverag tasklist setselect support gbcqek
# 18           2            initi java perspect switch slow gejhtl
# 19           4         dcr show packag view gd bce packag explor
# 20           4  classpath lost creat java project exist classp...
# 21           2               jdt chang listen effici issu gemn f
# 22           3     memori leak codeformatterpreferencepag ge wqu
# 23           3                  close project packag view gehflt
# 24           2                      show packag view work geme t
# 25           2         resourceexcept javamodelexcept packag geo
# 26           3                     java prefer page group gerrew
# 27           4   type confus binari select librari filter geul a
# 28           3  refactor variabl extract lead incorrect code g...
# 29           2  viewer free expans jar happen delet project ge...
# ...        ...                                                ...
# 7343         1            styledtext freez textlayout computerun
# 7344         1                       mis configur perform machin
# 7345         1    hipp instanc sphinx eatop broken upgrad hudson
# 7346         1             hipp m e instanc broken upgrad hudson
# 7347         2                 wrong focu behavior search dialog
# 7348         1                             thym hipp fail upgrad
# 7349         4                papyru remov branch git repositori
# 7350         1                        upgrad hipp e updat plugin
# 7351         1  uss eclips protocolexcept server fail respond ...
# 7352         3                            display employ committ
# 7353         1  org eclipse jgit api errors transportexcept gi...
# 7354         3                  check restart window test machin
# 7355         3                      patch stuck submit merg pend
# 7356         2                       bugzilla failur email notif
# 7357         1  share instanc hudson slave newer version java ...
# 7358         1         contact build eclipse org build slow time
# 7359         1  build gef hipp fail proxy eclipse org unknown ...
# 7360         1               uss modifi respons send bodi entiti
# 7361         1  uss retriev request if none match found applic...
# 7362         2        uss delet content respons send bodi entiti
# 7363         1                                            gerrit
# 7364         1                      error report vm friday night
# 7365         2                           scout delet wrong tag v
# 7366         3  renam eclips collect github repo collect eclip...
# 7367         1                         polarsi ca login bugzilla
# 7368         2                oomph hipp permiss problem restart
# 7369         1             upgrad hipp instanc fail eclips scada
# 7370         3           hipp java latest bit version bit requir
# 7371         1                                thym hipp miss gtk
# 7372         2                      upgrad jgit hipp hudson fail
#
#                                             description
# 0     project junk releas teamstream renam project a...
# 1     ak pm except night work home connect internet ...
# 2     dbcs pde sourc page plug in manifest editor di...
# 3     dbc except thread error messag launch plug in ...
# 4     problem problem ran target eclips debugg a ins...
# 5     support contribut view automat startup contrib...
# 6     open wizard dialog select basic file notic fin...
# 7     project pde project text haveth focu start typ...
# 8     wizard banner resid acord text show open java ...
# 9     pde wizard append jre lib properti name compil...
# 10    pm vaj execut class implement method interfac ...
# 11    creat class class wizard creat entri local his...
# 12    tm sdk smoke test setup move packag junit exte...
# 13    creat java project junit packag view renam tes...
# 14    creat class code public class class class inne...
# 15    gotomark set sourc rang updat outlin view java...
# 16    ak pm remind db class int extract super call c...
# 17    pm ne tasklist setselect iselect select setsel...
# 18    pm host workspac set up delet workbench xml fi...
# 19    packag view option file show navig nice revers...
# 20    directori java project creat earlier occas wor...
# 21    classfilemarkerannotationmodel visit optim fma...
# 22    ak pm codeformatterpreferencepag hold property...
# 23    ak pm close project action packag view note pm...
# 24    show packag view outlin work zoom project pack...
# 25    core team awar case sensit issu point pr packa...
# 26    pm java prefer page space group packag view re...
# 27    filter librari packag view select goto type se...
# 28    extract method code start end result invalid s...
# 29    setup java perspect creat java project javapro...
# ...                                                 ...
# 7343  n problem occur dialog rebuild encount problem...
# 7344  http hudson eclipse org perftests view eclips ...
# 7345  http hudson eclipse org sphinx http hudson ecl...
# 7346  upgrad hudson http hudson eclipse org m e fail...
# 7347  build i notic open search dialog ctrl h past s...
# 7348  trigger hipp upgrad user panel eclips thym pro...
# 7349  mistakenli creat branch repositori remov undes...
# 7350  user page trigger updat hipp e http hudson ecl...
# 7351  chri test case test conflict invalid if match ...
# 7352  ve notic re includ employ place display commit...
# 7353  deni start work uss sdk build git repo ca acce...
# 7354  night window test machin run ui test correctli...
# 7355  patch stuck statu submit merg pend start happe...
# 7356  consist error today creat updat bug prevent cr...
# 7357  build fail yesterday window fail due network i...
# 7358  maven build http build eclipse org eclipse bui...
# 7359  gef mast fail error error com google inject ex...
# 7360  m protocol except pars respons after success m...
# 7361  request creat updat blob put http api staging ...
# 7362  m protocol except pars respons after success c...
# 7363  timeout push chang request server unavail view...
# 7364  track request email outag complet turn error r...
# 7365  delet tag v scout org eclipse scout rt commit ...
# 7366  eclips collect github repo name collect renam ...
# 7367  ca login polarsi bugzilla http polarsys org bu...
# 7368  yesterday restart hipp longer write folder own...
# 7369  upgrad eclips scada hudson fail shut hudson bu...
# 7370  tcf project unit test fail eclips neon bit lib...
# 7371  thym hipp error log run ui test java lang unsa...
# 7372  upgrad jgit hipp hudson hipp servic portal app...
#
# [7373 rows x 3 columns]

# %%
severity = df['severity']
counts = severity.value_counts(ascending=True)

total_count = len(severity)

class_probability = [0] * 6


for i in range(1, 6):
    class_probability[i] = counts.loc[i] / total_count
    


if sum(class_probability) != 1:
    raise Error("Probability mismatch.")

# %%
class_group = df.groupby('severity')

from collections import defaultdict
word_count_per_class = defaultdict(lambda : [0, 0, 0, 0, 0, 0])
total_words_per_class = [0, 0, 0, 0, 0, 0]

vocabulary = set()
for key, group in class_group:    
    summaries = group['summary']    
    for summary in summaries:        
        words = summary.split()        
        total_words_per_class[key] += len(words)
        for word in words:
            vocabulary.add(word)
            word_count_per_class[word][key] += 1
        
    
        

(len(vocabulary), total_words_per_class)
# Out:
# (4888, [0, 4071, 8099, 17715, 9136, 5165])

# %%
def probability_of_word_given_class(words, clazz):
    "P(Word|Class) = (Occurence of word in class + 1) / (total words in class + total words in vocabulary)"
    
    denominator = total_words_per_class[clazz] + len(vocabulary)
    
    for word in words:
        yield (word_count_per_class[word][clazz] + 1) / denominator

# %%
from functools import reduce
import operator

def predict_severity(summary):
    """
    P(Class|Words) = P(Word_1|Class) * P(Word_2|Class) ... * P(Class)
        
    class = argmax(P(Class|Words))
    """
    
    words = summary.split()
    class_probability_given_summary = [0, 0, 0, 0, 0, 0]
    
    for clazz in range(1,6):
        product_of_words_probability = (reduce(operator.mul, probability_of_word_given_class(words, clazz)))
        print(product_of_words_probability)
        class_probability_given_summary[clazz] = product_of_words_probability  * class_probability[clazz]
    
    return class_probability_given_summary.index(max(class_probability_given_summary))

# %%
from pprint import pprint
def measure_accuracy(test_data):
    result_matrix = [[0, 0, 0, 0, 0, 0] for _ in range(7)]
    
    for data in test_data:
        print(data, type(data))
    
    
    
measure_accuracy(df.iloc[:5])
# Out:
# severity <class 'str'>
# summary <class 'str'>
# description <class 'str'>

# %%
(predict_severity(df['summary'][103]), df['severity'][103])
# Out:
# 1.2951930169518469e-24
# 5.370194446802706e-22
# 1.2607531769381076e-21
# 6.892748443024496e-22
# 9.366913011329491e-24
# (3, 3)
